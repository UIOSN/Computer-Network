# %%
from huawei import router1, router2, HuaweiRouter
from pathlib import Path

log_dir = Path("log")
config_router1 = Path("router1.txt")
config_router2 = Path("router2.txt")

# %%
with HuaweiRouter(router1, log_dir=log_dir) as R1:
    R1.configure(config_router1)
# Out:
# log\Router1_20251201-150015.log
# [INFO] Connected to Router1 (172.16.2.203)
# [INFO] Applying configuration from router1.txt to Router1 (172.16.2.203)
# system-view
# Enter system view, return user view with Ctrl+Z.
# [AR6140-02-1]dhcp enable
# [AR6140-02-1]ip pool net1
# Info: The parameter is case insensitive. All uppercase letters in the string will be converted to lowercase letters.
# Info: It is successful to create an IP address pool.
# [AR6140-02-1-ip-pool-net1]network 192.168.1.0 mask 255.255.255.0
# [AR6140-02-1-ip-pool-net1]gateway-list 192.168.1.1
# [AR6140-02-1-ip-pool-net1]quit
# [AR6140-02-1]observe-port interface GigabitEthernet 0/0/3
# [AR6140-02-1]interface GigabitEthernet0/0/0
# [AR6140-02-1-GigabitEthernet0/0/0]ip address 192.168.1.1 24
# [AR6140-02-1-GigabitEthernet0/0/0]dhcp select global
# [AR6140-02-1-GigabitEthernet0/0/0]mirror to observe-port both
# Warning: Get packets will be sent to observe port
# [AR6140-02-1-GigabitEthernet0/0/0]quit
# [AR6140-02-1]interface GigabitEthernet0/0/1
# [AR6140-02-1-GigabitEthernet0/0/1]ip address 192.168.12.1 24
# [AR6140-02-1-GigabitEthernet0/0/1]ospf authentication-mode simple plain 111111
# Warning: The algorithm is not safe, and hmac-sha256 is recommended.
# Warning: After plaintext mode is specified, the password will be saved in plaintext in the configuration file, which has
#  a high security risk.
# [AR6140-02-1-GigabitEthernet0/0/1]mirror to observe-port both
# Warning: Get packets will be sent to observe port
# [AR6140-02-1-GigabitEthernet0/0/1]quit
# [AR6140-02-1]interface GigabitEthernet0/0/2
# [AR6140-02-1-GigabitEthernet0/0/2]ip address 192.168.13.1 24
# [AR6140-02-1-GigabitEthernet0/0/2]ospf authentication-mode simple plain 111111
# Warning: The algorithm is not safe, and hmac-sha256 is recommended.
# Warning: After plaintext mode is specified, the password will be saved in plaintext in the configuration file, which has
#  a high security risk.
# [AR6140-02-1-GigabitEthernet0/0/2]mirror to observe-port both
# Warning: Get packets will be sent to observe port
# [AR6140-02-1-GigabitEthernet0/0/2]quit
# [AR6140-02-1]router id 1.1.1.1
# Info: Router ID has been modified, please reset the relative protocols manually to update the Router ID.
# [AR6140-02-1]ospf
# [AR6140-02-1-ospf-1]area 0
# [AR6140-02-1-ospf-1-area-0.0.0.0]network 192.168.1.0 0.0.0.255
# [AR6140-02-1-ospf-1-area-0.0.0.0]network 192.168.12.0 0.0.0.255
# [AR6140-02-1-ospf-1-area-0.0.0.0]network 192.168.13.0 0.0.0.255
# [AR6140-02-1-ospf-1-area-0.0.0.0]quit
# [AR6140-02-1-ospf-1]quit
# [AR6140-02-1]return
# <AR6140-02-1>
# [INFO] Disconnected from Router1 (172.16.2.203)

# %%
with HuaweiRouter(router2, log_dir=log_dir) as R2:
    R2.configure(config_router2)
# Out:
# log\Router2_20251201-144939.log
# [INFO] Connected to Router2 (172.16.2.204)
# [INFO] Applying configuration from router2.txt to Router2 (172.16.2.204)
# system-view
# Enter system view, return user view with Ctrl+Z.
# [AR2200-02-2]dhcp enable
# [AR2200-02-2]ip pool net2
# Info: It is successful to create an IP address pool.
# [AR2200-02-2-ip-pool-net2]network 192.168.2.0 mask 255.255.255.0
# [AR2200-02-2-ip-pool-net2]gateway-list 192.168.2.1
# [AR2200-02-2-ip-pool-net2]quit
# [AR2200-02-2]interface GigabitEthernet0/0/5
# [AR2200-02-2-GigabitEthernet0/0/5]ip address 192.168.12.2 24
# [AR2200-02-2-GigabitEthernet0/0/5]ospf authentication-mode simple plain 111111
# Warning: The algorithm is not safe, and hmac-sha256 is recommended.
# Warning: After plaintext mode is specified, the password will be saved in plaintext in the configuration file, which has
#  a high security risk.
# [AR2200-02-2-GigabitEthernet0/0/5]quit
# [AR2200-02-2]interface GigabitEthernet0/0/6
# [AR2200-02-2-GigabitEthernet0/0/6]ip address 192.168.24.1 24
# [AR2200-02-2-GigabitEthernet0/0/6]ospf authentication-mode simple plain 111111
# Warning: The algorithm is not safe, and hmac-sha256 is recommended.
# Warning: After plaintext mode is specified, the password will be saved in plaintext in the configuration file, which has
#  a high security risk.
# [AR2200-02-2-GigabitEthernet0/0/6]quit
# [AR2200-02-2]interface GigabitEthernet0/0/7
# [AR2200-02-2-GigabitEthernet0/0/7]ip address 192.168.2.1 24
# [AR2200-02-2-GigabitEthernet0/0/7]dhcp select global
# [AR2200-02-2-GigabitEthernet0/0/7]quit
# [AR2200-02-2]router id 2.2.2.2
# Info: Router ID has been modified, please reset the relative protocols manually to update the Router ID.
# [AR2200-02-2]ospf
# [AR2200-02-2-ospf-1]area 0
# [AR2200-02-2-ospf-1-area-0.0.0.0]network 192.168.12.0 0.0.0.255
# [AR2200-02-2-ospf-1-area-0.0.0.0]network 192.168.24.0 0.0.0.255
# [AR2200-02-2-ospf-1-area-0.0.0.0]network 192.168.2.0 0.0.0.255
# [AR2200-02-2-ospf-1-area-0.0.0.0]quit
# [AR2200-02-2-ospf-1]quit
# [AR2200-02-2]return
# <AR2200-02-2>
# [INFO] Disconnected from Router2 (172.16.2.204)
